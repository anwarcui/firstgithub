# %%
# Import Libiraries 
import seaborn as sns

# Canvas (Bolean Board)
sns.set(style='whitegrid')

kashti = sns.load_dataset("titanic")

sns.boxenplot(x="class",
              y="fare",
              data=kashti)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %% [markdown]
# ---

# %%
# Import Libiraries 
import seaborn as sns

# Canvas (Bolean Board)
sns.set(style='whitegrid')

tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.boxenplot(x="day",y="tip", data=tips, saturation=1)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# ---

# %%
# Import Libiraries 
import seaborn as sns
import pandas as pd
import numpy as np


tip = sns.load_dataset("tips")
tip.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Import Libiraries 
import seaborn as sns

# Canvas (Bolean Board)
sns.set(style='whitegrid')

tips = sns.load_dataset("tips")

sns.boxplot(x=tip['tip'])
# Out:
# <Axes: xlabel='tip'>

# %% [markdown]
# ---

# %%
# Import Libiraries 
import seaborn as sns

# Canvas (Bolean Board)
sns.set(style='whitegrid')

tips = sns.load_dataset("tips")
sns.boxplot(x="tip", y="day", hue="smoker", data=tip, palette="Set2", dodge=True)
# How to give different color for hue
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %% [markdown]
# ## Vertical and Horizental Function

# %%
# Import Libiraries 
import seaborn as sns

# Canvas (Bolean Board)
sns.set(style='whitegrid')

kashti = sns.load_dataset("tips")

sns.boxenplot(x="day", y="tip", data=kashti, saturation=1, color="#cc2bcc")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
import seaborn as sns
import pandas as pd
import numpy as np

kashti = sns.load_dataset("titanic")
kashti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.boxplot(x="sex", y="fare", data=kashti)
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
kashti
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import matplotlib.pyplot as plt
sns.boxplot(x="survived", y="age", showmeans=True, meanprops={
    "marker":"*", "markersize": "12", "markeredgecolor":"red"}, data=kashti)
# Show Labels
plt.xlabel("How many survived", size="12")
plt.ylabel("Age (years)", size="12")
plt.title("Box plot of kitny adami duby aur kitny bach gy", size=14, weight='bold')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### Assigment
# - facet wrap and facet grid ?

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt
  
# loading of a dataframe from seaborn
kashti = seaborn.load_dataset('tips')
  
############# Main Section         #############
# Form a facetgrid using columns with a hue
g1 = sns.FacetGrid(kashti, col ="sex",  hue ="day")
# map the above form facetgrid with some attributes
g1.map(plt.scatter, "total_bill", "tip", edgecolor ="w").add_legend()
# show the object
plt.show()
  
# This code is contributed by Deepanshu Rustagi.

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt
  
# loading of a dataframe from seaborn
kashti = seaborn.load_dataset('tips')
  
############# Main Section         #############
# Form a facetgrid using columns with a hue
g1 = sns.FacetGrid(kashti, row ="smoker",  col ="time")
# map the above form facetgrid with some attributes
g1.map(plt.hist, "total_bill", bins = 15, color ="orange")
# show the object
plt.show()
  
# This code is contributed by Deepanshu Rustagi.

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt
  
# loading of a dataframe from seaborn
kashti = seaborn.load_dataset('tips')
  
############# Main Section         #############
# Form a facetgrid using columns with a hue
g1 = sns.FacetGrid(df, col ="time",  hue ="smoker")
# map the above form facetgrid with some attributes
g1.map(sns.regplot, "total_bill", "tip").add_legend()
# show the object
plt.show()
  
# This code is contributed by Deepanshu Rustagi.
